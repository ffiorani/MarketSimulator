# %%
import pandas as pd

prices = pd.read_csv('./priceHistory.csv')
prices.columns = ['price']

prices.plot(kind='line')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

wealth_df = pd.read_csv('./wealth.csv')

wealth_df.hist()
plt.xlabel('Wealth')
plt.ylabel('Frequency')
plt.title('Histogram of Wealth')
plt.show()

# %%
wealth_df.head()
# Out:
#    -27069.1
# 0  -26821.7
# 1  -26673.4
# 2  -25147.1
# 3  -23931.6
# 4  -23618.7
