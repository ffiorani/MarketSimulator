# %%
import pandas as pd

prices = pd.read_csv('./build/app/priceHistory.csv')
prices.columns = ['price']

prices.plot(kind='line')
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

wealth_df = pd.read_csv('./build/app/wealth.csv')

sns.histplot(wealth_df)
plt.xlabel('Wealth')
plt.ylabel('Frequency')
plt.title('Histogram of Wealth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 wealth_df = pd.read_csv('./build/app/wealth.csv')
#       6 sns.histplot(wealth_df)
# ----> 7 plt.xlabel('Wealth')
#       8 plt.ylabel('Frequency')
#       9 plt.title('Histogram of Wealth')
#
# NameError: name 'plt' is not defined

# %%
wealth_df.head()
# Out:
#    -27069.1
# 0  -26821.7
# 1  -26673.4
# 2  -25147.1
# 3  -23931.6
# 4  -23618.7
